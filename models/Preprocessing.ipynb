# %% [markdown]
# <h1> Preprocessing: </h1>
#
#
# Using different text to vector encodings like TF-IDF for word priority within articles and SBERT for extracting semantic meaning within related wikipedia articles

# %% [markdown]
# <h3> #1 Using TF-IDF encoding </h3>

# %%
import os
import pandas as pd

df = pd.read_csv(os.path.abspath(os.fake_news_dataset.csv))
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2 import pandas as pd
# ----> 4 df = pd.read_csv(os.path.abspath(os.fake_news_dataset.csv))
#       5 print(df.head())
#
# AttributeError: module 'os' has no attribute 'fake_news_dataset'
